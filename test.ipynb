# %% [markdown]
# # Example

# %%
import numpy as np 
height = np.random.normal(loc=5.5, scale=0.5/3, size=10000)
height
# Out:
# array([5.48824327, 5.38228907, 5.59658232, ..., 5.42549773, 5.28401343,
#        5.2559436 ])

# %%
import seaborn as sns

# %%
sns.histplot(height, kde=True)
# Out:
# <Axes: ylabel='Count'>
